# %%
import nltk
from nltk.corpus import brown

#Separates by sentence
print(brown.tagged_sents()[:2], '\n')
#Separates by word
print(brown.tagged_words()[:50])
#Lists the categories
brown.categories()
#Selected humorous words
print(brown.tagged_words(categories="humor")[:50])
#Different tagged corpus
nltk.corpus.nps_chat.tagged_words()[:50]
# Out:
# [[('The', 'AT'), ('Fulton', 'NP-TL'), ('County', 'NN-TL'), ('Grand', 'JJ-TL'), ('Jury', 'NN-TL'), ('said', 'VBD'), ('Friday', 'NR'), ('an', 'AT'), ('investigation', 'NN'), ('of', 'IN'), ("Atlanta's", 'NP$'), ('recent', 'JJ'), ('primary', 'NN'), ('election', 'NN'), ('produced', 'VBD'), ('``', '``'), ('no', 'AT'), ('evidence', 'NN'), ("''", "''"), ('that', 'CS'), ('any', 'DTI'), ('irregularities', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('.', '.')], [('The', 'AT'), ('jury', 'NN'), ('further', 'RBR'), ('said', 'VBD'), ('in', 'IN'), ('term-end', 'NN'), ('presentments', 'NNS'), ('that', 'CS'), ('the', 'AT'), ('City', 'NN-TL'), ('Executive', 'JJ-TL'), ('Committee', 'NN-TL'), (',', ','), ('which', 'WDT'), ('had', 'HVD'), ('over-all', 'JJ'), ('charge', 'NN'), ('of', 'IN'), ('the', 'AT'), ('election', 'NN'), (',', ','), ('``', '``'), ('deserves', 'VBZ'), ('the', 'AT'), ('praise', 'NN'), ('and', 'CC'), ('thanks', 'NNS'), ('of', 'IN'), ('the', 'AT'), ('City', 'NN-TL'), ('of', 'IN-TL'), ('Atla
# ...

# %%
from nltk.corpus import treebank

treebank_words = treebank.raw()
treebank_words[:50]

treebank_tokens = treebank.words()
treebank.tagged_words()[:50]
# Out:
# [('Pierre', 'NNP'),
#  ('Vinken', 'NNP'),
#  (',', ','),
#  ('61', 'CD'),
#  ('years', 'NNS'),
#  ('old', 'JJ'),
#  (',', ','),
#  ('will', 'MD'),
#  ('join', 'VB'),
#  ('the', 'DT'),
#  ('board', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('nonexecutive', 'JJ'),
#  ('director', 'NN'),
#  ('Nov.', 'NNP'),
#  ('29', 'CD'),
#  ('.', '.'),
#  ('Mr.', 'NNP'),
#  ('Vinken', 'NNP'),
#  ('is', 'VBZ'),
#  ('chairman', 'NN'),
#  ('of', 'IN'),
#  ('Elsevier', 'NNP'),
#  ('N.V.', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Dutch', 'NNP'),
#  ('publishing', 'VBG'),
#  ('group', 'NN'),
#  ('.', '.'),
#  ('Rudolph', 'NNP'),
#  ('Agnew', 'NNP'),
#  (',', ','),
#  ('55', 'CD'),
#  ('years', 'NNS'),
#  ('old', 'JJ'),
#  ('and', 'CC'),
#  ('former', 'JJ'),
#  ('chairman', 'NN'),
#  ('of', 'IN'),
#  ('Consolidated', 'NNP'),
#  ('Gold', 'NNP'),
#  ('Fields', 'NNP'),
#  ('PLC', 'NNP'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('named', 'VBN'),
#  ('*-1', '-NONE-'),
#  ('a', 'DT')]

# %% [markdown]
# Choose a corpus from any of the NLTK books or Gutenberg. Tokenize the corpus and run a POS tagger, either the Bigram tagger t2 that we defined in lab, or the Stanford tagger, nltk.pos_tag, on the tokens.
#
# Post the frequencies of either the POS tags or the classes of POS tags from your corpus.
#
# Note that you should do the processing steps from the last section of the lab:
#
# split the raw text into sentences,
#
# tokenize the list of sentences
#
# then run the tagger on the list of sentences, where the result is a list of lists of (word, tag) pairs
#
# flatten the list to get just one list of (word, tag)
#
# put either the tags or the first letter of the tags into a Frequency Distribution and print those (as we did in the first section of the lab)
#
# Report the corpus name, tokenizer, POS tagger and frequencies of the tags or classes of tags in the question for this week. Note any significant differences in the frequent tags or tag classes between your corpus and the Penn Treebank tags that we ran in the first part of the lab.
#
# You will be able to observe the tagging frequency results from other students’ work and compare the results.

# %%
import nltk
from nltk.corpus import treebank

#treebank tagged words
treebank_tag = treebank.tagged_sents()
#Training Size
size = int(len(treebank_tag) * 0.9)

#Treebank training set
treebank_train = treebank_tag[:size]
#Treebank test set
treebank_test = treebank_tag[size:]

#Default Tagger
t0 = nltk.DefaultTagger('NN')
#Most Frequent tagger
t1 = nltk.UnigramTagger(treebank_train, backoff= t0)
#Bigram tagger
t2 = nltk.BigramTagger(treebank_train, backoff=t1)

print("Tagger Accuracy: {:.4f}\n".format(t2.evaluate(treebank_test)))

#Reading Emma
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
#Tokenizing Emma Sentences
emma_tokens = nltk.sent_tokenize(emma)
#Tokenizing sentences into words
emma_tokens = [nltk.word_tokenize(s) for s in emma_tokens]

#Tagging Emma sentences
emma_tagged = nltk.pos_tag_sents(emma_tokens)
#Flattening the text
emma_tagged_flat = [w for sent in emma_tagged for w in sent]

#Creating frequency dictionary
emma_dict = nltk.FreqDist(t for w, t in emma_tagged_flat)

#Getting the number of words
emma_len = len(emma_tagged_flat)

for tag, count in emma_dict.most_common(len(emma_dict.items())):
    print("Tag: {:s}  \tFrequency: {:.4f}".format(tag, count / emma_len))
# Out:
# Tagger Accuracy: 0.8906
#
# Tag: NN  	Frequency: 0.1008
# Tag: IN  	Frequency: 0.0932
# Tag: PRP  	Frequency: 0.0814
# Tag: RB  	Frequency: 0.0678
# Tag: DT  	Frequency: 0.0664
# Tag: ,  	Frequency: 0.0627
# Tag: JJ  	Frequency: 0.0534
# Tag: NNP  	Frequency: 0.0474
# Tag: VBD  	Frequency: 0.0472
# Tag: VB  	Frequency: 0.0466
# Tag: .  	Frequency: 0.0419
# Tag: CC  	Frequency: 0.0361
# Tag: :  	Frequency: 0.0293
# Tag: TO  	Frequency: 0.0270
# Tag: PRP$  	Frequency: 0.0245
# Tag: VBN  	Frequency: 0.0242
# Tag: MD  	Frequency: 0.0231
# Tag: NNS  	Frequency: 0.0186
# Tag: VBP  	Frequency: 0.0177
# Tag: VBG  	Frequency: 0.0160
# Tag: ''  	Frequency: 0.0133
# Tag: VBZ  	Frequency: 0.0116
# Tag: ``  	Frequency: 0.0096
# Tag: WP  	Frequency: 0.0047
# Tag: WRB  	Frequency: 0.0047
# Tag: POS  	Frequency: 0.0045
# Tag: CD  	Frequency: 0.0041
# Tag: WDT  	Frequency: 0.0038
# Tag: JJR  	Frequency: 0.0028
# Tag: RP  	Frequency: 0.0024
# Tag: EX  	Frequency: 0.0024
# Tag: JJS  	Frequency: 0.0023
# ...

# %%
tree_len = len(treebank.words())
treeDict = nltk.FreqDist([t for w, t in treebank.tagged_words()])
for t, c in treeDict.most_common(len(treeDict.items())):
    print("Tag: {:s}  \tFrequenct: {:.4f}".format(t, c / tree_len))
# Out:
# Tag: NN  	Frequenct: 0.1308
# Tag: IN  	Frequenct: 0.0979
# Tag: NNP  	Frequenct: 0.0935
# Tag: DT  	Frequenct: 0.0811
# Tag: -NONE-  	Frequenct: 0.0655
# Tag: NNS  	Frequenct: 0.0601
# Tag: JJ  	Frequenct: 0.0579
# Tag: ,  	Frequenct: 0.0485
# Tag: .  	Frequenct: 0.0385
# Tag: CD  	Frequenct: 0.0352
# Tag: VBD  	Frequenct: 0.0302
# Tag: RB  	Frequenct: 0.0280
# Tag: VB  	Frequenct: 0.0254
# Tag: CC  	Frequenct: 0.0225
# Tag: TO  	Frequenct: 0.0216
# Tag: VBN  	Frequenct: 0.0212
# Tag: VBZ  	Frequenct: 0.0211
# Tag: PRP  	Frequenct: 0.0170
# Tag: VBG  	Frequenct: 0.0145
# Tag: VBP  	Frequenct: 0.0131
# Tag: MD  	Frequenct: 0.0092
# Tag: POS  	Frequenct: 0.0082
# Tag: PRP$  	Frequenct: 0.0076
# Tag: $  	Frequenct: 0.0072
# Tag: ``  	Frequenct: 0.0071
# Tag: ''  	Frequenct: 0.0069
# Tag: :  	Frequenct: 0.0056
# Tag: WDT  	Frequenct: 0.0044
# Tag: JJR  	Frequenct: 0.0038
# Tag: NNPS  	Frequenct: 0.0024
# Tag: WP  	Frequenct: 0.0024
# Tag: RP  	Frequenct: 0.0021
# ...

# %%
emma_tagged_flat[:50]
# Out:
# [('[', 'NNS'),
#  ('Emma', 'NNP'),
#  ('by', 'IN'),
#  ('Jane', 'NNP'),
#  ('Austen', 'NNP'),
#  ('1816', 'CD'),
#  (']', 'NNP'),
#  ('VOLUME', 'NNP'),
#  ('I', 'PRP'),
#  ('CHAPTER', 'VBP'),
#  ('I', 'PRP'),
#  ('Emma', 'NNP'),
#  ('Woodhouse', 'NNP'),
#  (',', ','),
#  ('handsome', 'NN'),
#  (',', ','),
#  ('clever', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('rich', 'JJ'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('comfortable', 'JJ'),
#  ('home', 'NN'),
#  ('and', 'CC'),
#  ('happy', 'JJ'),
#  ('disposition', 'NN'),
#  (',', ','),
#  ('seemed', 'VBD'),
#  ('to', 'TO'),
#  ('unite', 'VB'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('blessings', 'NNS'),
#  ('of', 'IN'),
#  ('existence', 'NN'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('had', 'VBD'),
#  ('lived', 'VBN'),
#  ('nearly', 'RB'),
#  ('twenty-one', 'CD'),
#  ('years', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('with', 'IN')]
